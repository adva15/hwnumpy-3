# %%
import numpy as np

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.1-cp312-cp312-win_amd64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.56.0-cp312-cp312-win_amd64.whl.metadata (103 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (11.1.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.1-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------ --------------------------------- 1.3/8.1 MB 8.4 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 13.4 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.0 MB/s eta 0:00:00
# Downloading contourpy-1.3.1-cp312-cp312-win_amd64.whl (220 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.56.0-cp312-cp312-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 13.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp312-cp312-win_amd64.whl (71 kB)
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.1 pyparsing-3.2.1

# %%
# Out:
# Requirement already satisfied: Image in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (1.5.33)
# Requirement already satisfied: pillow in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (from Image) (11.1.0)
# Requirement already satisfied: django in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (from Image) (5.1.7)
# Requirement already satisfied: six in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (from Image) (1.17.0)
# Requirement already satisfied: asgiref<4,>=3.8.1 in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (from django->Image) (3.8.1)
# Requirement already satisfied: sqlparse>=0.3.1 in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (from django->Image) (0.5.3)
# Requirement already satisfied: tzdata in c:\users\aadva\appdata\local\programs\python\python312\lib\site-packages (from django->Image) (2025.1)

# %%
from skimage import io
photo = io.imread('jinny.jpg')

import matplotlib.pyplot as plt
plt.imshow(photo)

#a
print(type(photo))
print(photo.shape)
# Out:
# <class 'numpy.ndarray'>
# (222, 147, 3)

# %%
#b
plt.imshow(photo[:, :50 ,:])

# %%
#c
from skimage import io
from PIL import Image
photo = io.imread('jinny.jpg')
photo_pil = Image.fromarray(photo)
photo = photo_pil.rotate(120)
import matplotlib.pyplot as plt
plt.imshow(photo)
